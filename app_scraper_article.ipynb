# %% [markdown]
# # **App scraper - Article methodology**
#
# This methodology is based on the methodology detailed in the article "Automatic market research of mobile health apps for the self‐management of allergic rhinitis".

# %% [markdown]
# ## **[Setup]**

# %%
# !pip install google-play-scraper pandas requests python-dateutil

import requests
import time
import logging
import pandas as pd
import re
from datetime import datetime
from dateutil.relativedelta import relativedelta
from dateutil import parser
from google_play_scraper import search
# Out:
# Requirement already satisfied: google-play-scraper in c:\users\szymo\miniconda3\envs\adm\lib\site-packages (1.2.7)
# Requirement already satisfied: pandas in c:\users\szymo\miniconda3\envs\adm\lib\site-packages (2.3.3)
# Requirement already satisfied: requests in c:\users\szymo\miniconda3\envs\adm\lib\site-packages (2.32.5)
# Requirement already satisfied: python-dateutil in c:\users\szymo\miniconda3\envs\adm\lib\site-packages (2.9.0.post0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\szymo\miniconda3\envs\adm\lib\site-packages (from pandas) (2.3.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\szymo\miniconda3\envs\adm\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\szymo\miniconda3\envs\adm\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\szymo\miniconda3\envs\adm\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\szymo\miniconda3\envs\adm\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\szymo\miniconda3\envs\adm\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\szymo\miniconda3\envs\adm\lib\site-packages (from requests) (2025.10.5)
# Requirement already satisfied: six>=1.5 in c:\users\szymo\miniconda3\envs\adm\lib\site-packages (from python-dateutil) (1.17.0)

# %% [markdown]
# ## **[Configuration - Methodology Alignment]**

# %%
# [Methodology: Search Scope]
KEYWORDS = [
    'hay fever',
    'hayfever',
    'asthma',
    'rhinitis',
    'allergic rhinitis'
]

# Countries defined in the article: USA, UK, Australia
COUNTRIES = ['us', 'gb', 'au']

# Result limits defined in the article
LIMIT_APPLE = 200
LIMIT_GOOGLE = 250

CSV_FILE_ALL = 'data/all_asthma_apps_raw.csv'
CSV_FILE_FILTERED = 'data/asthma_apps_filtered_relevant.csv'

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %% [markdown]
# ## **[Filtering Logic]**

# %%
def check_eligibility(app_data):
    """
    Implements the exclusion criteria (Table 1 & 2 of the article).
    Returns True if the app is 'Potentially Relevant'.
    """
    
    title = str(app_data.get('title', '')).lower()
    desc = str(app_data.get('description', '')).lower()
    full_text = title + " " + desc
    
    # 1. CATEGORY CHECK 
    # Allowed: Medical, Health & Fitness, Weather
    allowed_cats = ['medical', 'health & fitness', 'health_and_fitness', 'weather']
    app_cat = str(app_data.get('genre', '')).lower()
    if app_cat not in allowed_cats:
        return False, "Category mismatch"

    # 2. RECENCY CHECK 
    # Must be updated within last 3 years
    last_updated = app_data.get('updated')
    if last_updated:
        three_years_ago = datetime.now() - relativedelta(years=3)
        if last_updated < three_years_ago:
            return False, "Outdated (>3 years)"
    else:
        return False, "No date provided"

    # --- LOGICAL CONDITIONS (Table 2) ---
    
    # Condition 2: "symptom" in description
    if "symptom" not in desc:
        return False, "Condition 2 failed (No 'symptom' in desc)"

    # Condition 3: Exclusion of alternative medicine
    # "home remed*", "natural remed*", "homeopath*", "alternative med*", "acupressure"
    bad_keywords = r"home remed|natural remed|homeopath|alternative med|acupressure"
    if re.search(bad_keywords, full_text):
        return False, "Condition 3 failed (Alternative med)"

    # 5.1: Category Weather OR "pollen" in title
    cond_5_1 = (app_cat == 'weather') or ('pollen' in title)
    
    # 5.2: Specific keywords in DESCRIPTION
    # "symptom", "rhinitis", "hay fever", "hayfever", "asthma", "allerg*"
    kw_5_2 = r"symptom|rhinitis|hay fever|hayfever|asthma|allerg"
    cond_5_2 = bool(re.search(kw_5_2, desc))
    
    # Condition 5 Met? (5.1 AND 5.2)
    cond_5 = cond_5_1 and cond_5_2

    # 6.1: Specific keywords in TITLE or DESCRIPTION
    # "rhinitis", "hay fever", "hayfever", "respiratory allerg*"
    kw_6_1 = r"rhinitis|hay fever|hayfever|respiratory allerg"
    cond_6_1 = bool(re.search(kw_6_1, full_text))

    # Condition 6 Met? (NOT 5 AND 6.1)
    cond_6 = (not cond_5) and cond_6_1

    # Condition 1: 5 OR 6 is met
    if not (cond_5 or cond_6):
        return False, "Condition 1 failed (Relevance)"

    # Condition 4: Food exclusion
    # Exclude if "food" in text AND Condition 6.1 is NOT met
    if "food" in full_text and not cond_6_1:
         return False, "Condition 4 failed (Food app)"

    return True, "Relevant"

# %% [markdown]
# ## **[Unified Scraper Function]**

# %%
def scrape_and_filter():
    all_apps = {}

    # --- APPLE APP STORE ---
    logging.info("Starting Apple App Store Scrape...")
    for country in COUNTRIES:
        for keyword in KEYWORDS:
            logging.info(f"Apple: Searching '{keyword}' in '{country}'...")
            try:
                url = "https://itunes.apple.com/search"
                params = {
                    'term': keyword,
                    'country': country,
                    'media': 'software',
                    'limit': LIMIT_APPLE
                }
                response = requests.get(url, params=params, timeout=10)
                if response.status_code == 200:
                    results = response.json().get('results', [])
                    for item in results:
                        app_id = str(item.get('trackId'))

                        date_str = item.get('currentVersionReleaseDate', item.get('releaseDate'))
                        try:
                            updated_dt = parser.parse(date_str).replace(tzinfo=None) if date_str else None
                        except:
                            updated_dt = None

                        app_obj = {
                            'store': 'Apple',
                            'id': app_id,
                            'title': item.get('trackName'),
                            'developer': item.get('artistName'),
                            'description': item.get('description', ''),
                            'genre': item.get('primaryGenreName'),
                            'price': item.get('formattedPrice'),
                            'rating': item.get('averageUserRating'),
                            'updated': updated_dt,
                            'url': item.get('trackViewUrl'),
                            'country_found': country,
                            'keyword_found': keyword
                        }

                        key = f"apple_{app_id}"
                        if key not in all_apps:
                            all_apps[key] = app_obj
            except Exception as e:
                logging.error(f"Apple Error ({country}/{keyword}): {e}")
            time.sleep(1)

    # --- GOOGLE PLAY STORE ---
    logging.info("Starting Google Play Store Scrape...")
    for country in COUNTRIES:
        for keyword in KEYWORDS:
            logging.info(f"Google: Searching '{keyword}' in '{country}'...")
            try:
                results = search(
                    keyword,
                    lang='en', # Article implies English apps
                    country=country,
                    n_hits=LIMIT_GOOGLE
                )
                
                for item in results:
                    app_id = item.get('appId')
                    
                    app_obj = {
                        'store': 'Google',
                        'id': app_id,
                        'title': item.get('title'),
                        'developer': item.get('developer'),
                        'description': item.get('summary', '') + " " + item.get('description', ''),
                        'genre': item.get('genre', 'Health & Fitness'),
                        'price': item.get('priceText'),
                        'rating': item.get('score'),
                        'updated': None,
                        'url': item.get('url'),
                        'country_found': country,
                        'keyword_found': keyword
                    }
                    key = f"google_{app_id}"
                    if key not in all_apps:
                        all_apps[key] = app_obj
                        
            except Exception as e:
                logging.error(f"Google Error ({country}/{keyword}): {e}")
            time.sleep(1)

    # --- PROCESSING & FILTERING ---
    logging.info(f"Total raw unique apps found: {len(all_apps)}")
    
    filtered_apps = []

    for key, app in all_apps.items():
        if app['store'] == 'Google' and app['updated'] is None:
            try:
                from google_play_scraper import app as get_app_details
                details = get_app_details(app['id'], lang='en', country=app['country_found'])
                app['description'] = details.get('description', app['description'])
                app['genre'] = details.get('genre', app['genre'])
                if details.get('updated'):
                    app['updated'] = datetime.fromtimestamp(details['updated'])
            except:
                pass

        is_relevant, reason = check_eligibility(app)
        
        if is_relevant:
            filtered_apps.append(app)

    logging.info(f"Total apps after filtering: {len(filtered_apps)}")
    
    df = pd.DataFrame(filtered_apps)
    df.to_csv(CSV_FILE_FILTERED, index=False)
    logging.info(f"Saved relevant apps to {CSV_FILE_FILTERED}")


scrape_and_filter()
# Out:
# 2026-01-14 01:48:11,774 - INFO - Starting Apple App Store Scrape...
# 2026-01-14 01:48:11,775 - INFO - Apple: Searching 'hay fever' in 'us'...
# 2026-01-14 01:48:22,605 - INFO - Apple: Searching 'hayfever' in 'us'...
# 2026-01-14 01:48:26,546 - INFO - Apple: Searching 'asthma' in 'us'...
# 2026-01-14 01:48:32,601 - INFO - Apple: Searching 'rhinitis' in 'us'...
# 2026-01-14 01:48:38,311 - INFO - Apple: Searching 'allergic rhinitis' in 'us'...
# 2026-01-14 01:48:42,863 - INFO - Apple: Searching 'hay fever' in 'gb'...
# 2026-01-14 01:48:47,689 - INFO - Apple: Searching 'hayfever' in 'gb'...
# 2026-01-14 01:48:51,903 - INFO - Apple: Searching 'asthma' in 'gb'...
# 2026-01-14 01:48:56,968 - INFO - Apple: Searching 'rhinitis' in 'gb'...
# 2026-01-14 01:49:02,546 - INFO - Apple: Searching 'allergic rhinitis' in 'gb'...
# 2026-01-14 01:49:09,092 - INFO - Apple: Searching 'hay fever' in 'au'...
# 2026-01-14 01:49:13,314 - INFO - Apple: Searching 'hayfever' in 'au'...
# 2026-01-14 01:49:17,010 - INFO - Apple: Searching 'asthma' in 'au'...
# 2026-01-14 01:49:34,670 - INFO - Apple: Searching 'rhinitis' in 'au'...
# 2026-01-14 01:49:43,912 - INFO - Apple: Searching 'allergic rhinitis' in 'au'...
# 2026-01-14 01:49:49,904 - INFO - Starting Google Play Store Scrape...
# 2026-01-14 01:49:49,905 - INFO - Google: Searching 'hay fever' in 'us'...
# 2026-01-14 01:49:53,747 - INFO - Google: Searching 'hayfever' in 'us'...
# 2026-01-14 01:49:55,708 - INFO - Google: Searching 'asthma' in 'us'...
# 2026-01-14 01:49:57,381 - INFO - Google: Searching 'rhinitis' in 'us'...
# 2026-01-14 01:49:59,118 - INFO - Google: Searching 'allergic rhinitis' in 'us'...
# 2026-01-14 01:50:00,998 - INFO - Google: Searching 'hay fever' in 'gb'...
# 2026-01-14 01:50:02,876 - INFO - Google: Searching 'hayfever' in 'gb'...
# 2026-01-14 01:50:04,835 - INFO - Google: Searching 'asthma' in 'gb'...
# 2026-01-14 01:50:07,012 - INFO - Google: Searching 'rhinitis' in 'gb'...
# 2026-01-14 01:50:08,800 - INFO - Google: Searching 'allergic rhinitis' in 'gb'...
# 2026-01-14 01:50:10,456 - INFO - Google: Searching 'hay fever' in 'au'...
# 2026-01-14 01:50:13,331 - INFO - Google: Searching 'hayfever' in 'au'...
# 2026-01-14 01:50:15,084 - INFO - Google: Searching 'asthma' in 'au'...
# 2026-01-14 01:50:16,802 - INFO - Google: Searching 'rhinitis' in 'au'...
# 2026-01-14 01:50:47,754 - INFO - Google: Searching 'allergic rhinitis' in 'au'...
# 2026-01-14 01:50:49,842 - INFO - Total raw unique apps found: 760
# 2026-01-14 01:54:10,135 - INFO - Total apps after filtering: 35
# 2026-01-14 01:54:10,180 - INFO - Saved relevant apps to data/asthma_apps_filtered_relevant.csv

# %% [markdown]
# ## **[Read relevant & remove duplicates]**

# %%
relevant = pd.read_csv('data/asthma_apps_filtered_relevant.csv')
relevant_dedup = relevant.drop_duplicates(subset=['title'])
display(relevant_dedup)
# Out:
#      store                id                           title  \
# 0    Apple        1244428929  My Pollen Forecast - Allergies
# 1    Apple         707461899          Melbourne Pollen Count
# 2    Apple        1380057946  klarify: Pollen app, Hay fever
# 3    Apple        1640644173              Perth Pollen Count
# 4    Apple         914338280           Canberra Pollen Count
# 5    Apple        1244429473          My Pollen Forecast Pro
# 6    Apple        1474856970                     Pollen Wise
# 7    Apple        1610856212         Pollen Count & Forecast
# 8    Apple         983596216                        MASK-air
# 9    Apple        1642592299                           DocGo
# 10   Apple         988384559                     Pollen Club
# 11   Apple        6742685070                 Pollen Count UK
# 12   Apple        6741510555     AllerTrack: Allergy monitor
# 13   Apple        6754224062                    Pollen-Sense
# 14   Apple        6755714042     Allergy Buddy Daily Tracker
# 15   Apple        1480794597                         HeyAlly
# 16   Apple        6743779989     The Pollen Forecast Checker
# 17   Apple        1216709069               Allergy Sufferers
# 18   Apple        1252417620     Sensio Air: Allergy Tracker
# 19   Apple        6463696374  Pollen Buddy – Allergy Tracker
# 20   Apple        1536352311                  Health Weather
# 21   Apple        1597730467                            Sonu
# 22   Apple        6482578819  AirScope: Pollen & Air Quality
# 23   Apple        6445884942  Kleenex Pollen Count, Forecast
# 24   Apple        6751772861   Allergy Alert Pollen Forecast
# 25   Apple         506739051                    Pollenvarsel
# 26   Apple         515301928                         Pollen+
# 27   Apple         621301387                Dagens Pollental
# 28   Apple        1363721253     Ambee: Air Quality & Pollen
# 29  Google  me.klarify.klara   klarify: Pollen & Allergy App
#
#                             developer  \
# 0                    JRustonApps B.V.
# 1                   AirHealth Pty Ltd
# 2                       Alk-Abello AS
# 3                   AirHealth Pty Ltd
# 4                   AirHealth Pty Ltd
# 5                    JRustonApps B.V.
# 6                        Pollen Sense
# 7                       kevin penture
# 8                            MASK-AIR
# 9                          DocGo Inc.
# 10                     Pavel Baskakov
# 11                     Ishaan Vadgama
# 12  Datair Technology Private Limited
# 13                       Anoop Bansal
# 14                           Voluntis
# 15  Alliance Healthcare Group Limited
# 16             Vida Apps Incorporated
# 17  Aerobiology Research Laboratories
# 18                           WLAB LTD
# 19            Naturally Inviting, LLC
# 20                               雪平 王
# 21         Sound Health Systems, Inc.
# 22            Ingenio Productions LLC
# 23         Kimberly-Clark Corporation
# 24                       Mindweb GmbH
# 25                       Temalogic AB
# 26                    screencode GmbH
# 27              Astma-Allergi Danmark
# 28  Datair Technology Private Limited
# 29                     ALK Abelló A/S
#
#                                           description             genre  \
# 0   My Pollen Forecast is the best app for trackin...  Health & Fitness
# 1   The Melbourne Pollen App provides Victorians w...           Weather
# 2   Stay ahead of your hay fever with klarify. Use...           Medical
# 3   Empower yourself against allergies with the cu...           Weather
# 4   Canberra Pollen Count & Forecast: Your Allergy...           Weather
# 5   My Pollen Forecast Pro is the best app for tra...  Health & Fitness
# 6   Pollen Wise has reached version 5! We've been ...           Weather
# 7   Pollen Count & Alert is the ultimate companion...  Health & Fitness
# 8   The best application for monitoring allergic r...           Medical
# 9   URGENT CARE IN-HOME VISITS\n\nAvoid crowded wa...           Medical
# 10  With the Pollen Club app you can:\n- understan...           Medical
# 11  * Live Pollen Counts: Get accurate, hourly pol...           Weather
# 12  Take back control of your day with AllerTrack,...           Weather
# 13  Breathe smarter with Pollen Sense.\nPollen Sen...  Health & Fitness
# 14  Take Control of Allergies Today!\nDownload All...           Medical
# 15  Healthcare Made Simple with HeyAlly!\n\nCenter...  Health & Fitness
# 16  The Pollen Forecast Checker is a simple yet hi...           Weather
# 17  UPDATE: We have completely revamped the app fo...           Weather
# 18  Sensio Air Allergy & Pollen Tracker\nLearn you...           Medical
# 19  Breathe Easy with Pollen Buddy – Your Personal...  Health & Fitness
# 20  Health Weather is an APP that pays attention t...           Weather
# 21  SONU provides personalized, drug free, acousti...  Health & Fitness
# 22  AirScope provides hyper-local air quality data...           Weather
# 23  Your personalised pollen forecast, made for th...  Health & Fitness
# 24  Never be surprised by pollen again.\nPollen al...           Weather
# 25  Appen Pollenvarsel gir deg pollenprognoser for...           Weather
# 26  In co-operation with local and international i...  Health & Fitness
# 27  Dagens Pollental er den bedste måde at få dine...  Health & Fitness
# 28  Stay informed, stay prepared, and stay safe wi...           Weather
# 29  Use the klarify pollen and allergy app to log ...  Health & Fitness
#
#     price   rating              updated  \
# 0    Free  4.69147  2026-01-04 01:31:39
# 1    Free  4.50000  2025-11-25 01:29:44
# 2    Free  4.52325  2025-11-17 09:46:10
# 3    Free  4.66667  2025-11-25 01:30:09
# 4    Free  4.80000  2025-11-25 01:30:03
# 5   $4.99  4.57172  2026-01-04 01:29:10
# 6    Free  4.54631  2025-12-09 03:45:00
# 7    Free  4.42856  2025-12-23 08:57:33
# 8    Free  0.00000  2026-01-13 08:29:18
# 9    Free  4.50000  2025-09-25 18:41:26
# 10   Free  4.40000  2025-10-29 16:20:56
# 11   Free  0.00000  2025-03-17 02:38:03
# 12   Free  0.00000  2025-11-24 03:11:20
# 13   Free  5.00000  2025-10-23 12:44:47
# 14   Free  0.00000  2025-12-15 17:57:16
# 15   Free  0.00000  2025-04-23 23:24:17
# 16   Free  5.00000  2025-04-17 10:23:55
# 17   Free  0.00000  2025-10-10 02:11:31
# 18   Free  3.57627  2024-02-11 05:27:22
# 19   Free  2.66667  2024-07-03 21:57:44
# 20   Free  4.71232  2024-07-24 21:01:40
# 21   Free  4.68085  2025-12-14 19:11:02
# 22   Free  4.73170  2025-04-03 14:18:55
# 23   Free  3.97927  2025-12-11 04:57:23
# 24   Free  0.00000  2025-11-26 08:00:00
# 25   Free  0.00000  2023-05-08 06:27:54
# 26   Free  1.00000  2024-11-25 14:23:33
# 27   Free  0.00000  2024-04-25 17:10:23
# 28   Free  3.00000  2025-11-24 03:10:35
# 29    NaN  3.87000  2025-11-13 15:24:00
#
#                                                   url country_found  \
# 0   https://apps.apple.com/us/app/my-pollen-foreca...            us
# 1   https://apps.apple.com/us/app/melbourne-pollen...            us
# 2   https://apps.apple.com/us/app/klarify-pollen-a...            us
# 3   https://apps.apple.com/us/app/perth-pollen-cou...            us
# 4   https://apps.apple.com/us/app/canberra-pollen-...            us
# 5   https://apps.apple.com/us/app/my-pollen-foreca...            us
# 6   https://apps.apple.com/us/app/pollen-wise/id14...            us
# 7   https://apps.apple.com/us/app/pollen-count-for...            us
# 8   https://apps.apple.com/us/app/mask-air/id98359...            us
# 9   https://apps.apple.com/us/app/docgo/id16425922...            us
# 10  https://apps.apple.com/us/app/pollen-club/id98...            us
# 11  https://apps.apple.com/us/app/pollen-count-uk/...            us
# 12  https://apps.apple.com/us/app/allertrack-aller...            us
# 13  https://apps.apple.com/us/app/pollen-sense/id6...            us
# 14  https://apps.apple.com/us/app/allergy-buddy-da...            us
# 15  https://apps.apple.com/us/app/heyally/id148079...            us
# 16  https://apps.apple.com/us/app/the-pollen-forec...            us
# 17  https://apps.apple.com/us/app/allergy-sufferer...            us
# 18  https://apps.apple.com/us/app/sensio-air-aller...            us
# 19  https://apps.apple.com/us/app/pollen-buddy-all...            us
# 20  https://apps.apple.com/us/app/health-weather/i...            us
# 21  https://apps.apple.com/us/app/sonu/id159773046...            us
# 22  https://apps.apple.com/us/app/airscope-pollen-...            us
# 23  https://apps.apple.com/gb/app/kleenex-pollen-c...            gb
# 24  https://apps.apple.com/gb/app/allergy-alert-po...            gb
# 25  https://apps.apple.com/gb/app/pollenvarsel/id5...            gb
# 26  https://apps.apple.com/gb/app/pollen/id5153019...            gb
# 27  https://apps.apple.com/gb/app/dagens-pollental...            gb
# 28  https://apps.apple.com/au/app/ambee-air-qualit...            au
# 29                                                NaN            us
#
#    keyword_found
# 0      hay fever
# 1      hay fever
# 2      hay fever
# 3      hay fever
# 4      hay fever
# 5      hay fever
# 6      hay fever
# 7      hay fever
# 8      hay fever
# 9      hay fever
# 10     hay fever
# 11     hay fever
# 12     hay fever
# 13     hay fever
# 14     hay fever
# 15     hay fever
# 16     hay fever
# 17     hay fever
# 18      hayfever
# 19      hayfever
# 20        asthma
# 21        asthma
# 22      rhinitis
# 23     hay fever
# 24     hay fever
# 25     hay fever
# 26     hay fever
# 27     hay fever
# 28      rhinitis
# 29     hay fever

# %%
CSV_FILE_FILTERED_DEDUP = 'data/asthma_apps_filtered_relevant_dedup.csv'
relevant_dedup.to_csv(CSV_FILE_FILTERED_DEDUP, index=False)
